# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

def download_image(url):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content)).convert("RGB")
    return img

# %%
image_url = "https://www.alleycat.org/wp-content/uploads/2019/03/FELV-cat.jpg"#i use cat image
img = download_image(image_url)

plt.figure(figsize=(6,6))
plt.imshow(img)
plt.axis("off")
plt.title("Downloaded Image")
plt.show()

img.save("original_image.jpg")
print("Saved as original_image.jpg")
# Out:
# Saved as original_image.jpg
